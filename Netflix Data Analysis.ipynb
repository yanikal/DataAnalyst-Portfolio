# %%
#import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import requests

# %%
#import dataset
NET_data = pd.read_csv("Data/netflix_titles.csv")
NET_data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
#The shape function shows the no. of rows and columns contained in this data
NET_data.shape
# Out:
# (8807, 12)

# %%
#The size function shows the size of the data
NET_data.size
# Out:
# 105684

# %%
#This function is used to show the column name
NET_data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
#datatypes
NET_data.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
#The info function
NET_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
#Data cleaning
#Finding the duplicate records and null values
NET_data.duplicated() #function to find duplicate values
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Length: 8807, dtype: bool

# %%
#This function only retuned the top 5 rows and the bottom 5 rows its has not give the necessary information required to dictect the duplicate values in a dataset
NET_data[NET_data.duplicated()] #This fomular will only give data that contain duplicate values
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
#Finding Null Values
#Using isnull function will return the a series of boolean values to confirm null areas
NET_data.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False      True   True     True       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
NET_data.isnull().sum() #this will generate the total of null values in the dataset
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
#using seaborn to vizualize the nullvalues in the data set
import matplotlib.pyplot as plt
sns.heatmap(NET_data.isnull())
plt.show()

# %%
#For house of cards,Find the show id and the show's Director
NET_data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
NET_data[NET_data['title'].isin(['House of Cards'])]    #Using the isin() statement to filter the key word
# Out:
#      show_id     type           title director  \
# 1059   s1060  TV Show  House of Cards      NaN
#
#                                                    cast        country  \
# 1059  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           date_added  release_year rating   duration                listed_in  \
# 1059  April 14, 2021          2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             description
# 1059  A ruthless politician will stop at nothing to ...

# %%
NET_data[NET_data['title'].str.contains('House of Cards')]    #Using the str.contains() to filter key word
# Out:
#      show_id     type           title director  \
# 1059   s1060  TV Show  House of Cards      NaN
#
#                                                    cast        country  \
# 1059  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           date_added  release_year rating   duration                listed_in  \
# 1059  April 14, 2021          2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             description
# 1059  A ruthless politician will stop at nothing to ...

# %%
 pd.to_datetime(NET_data['date_added']) #convert release columns into Datetime
# Out:
# 0      2021-09-25
# 1      2021-09-24
# 2      2021-09-24
# 3      2021-09-24
# 4      2021-09-24
#           ...
# 8802   2019-11-20
# 8803   2019-07-01
# 8804   2019-11-01
# 8805   2020-01-11
# 8806   2019-03-02
# Name: date_added, Length: 8807, dtype: datetime64[ns]

# %%
NET_data.dtypes #verify
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
NET_data['Date_Released'] = pd.to_datetime(NET_data['date_added']) #save in a new column

# %%
NET_data['Date_Released'].dt.year.value_counts()   #the value_counts()function helps to count distinct values in the mentioned column
# Out:
# 2019.0    2016
# 2020.0    1879
# 2018.0    1649
# 2021.0    1498
# 2017.0    1188
# 2016.0     429
# 2015.0      82
# 2014.0      24
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2009.0       2
# 2008.0       2
# 2010.0       1
# Name: Date_Released, dtype: int64

# %%
#Using a Bar chart
NET_data['Date_Released'].dt.year.value_counts().plot(kind ='bar', color= 'navy') 
plt.title("Frequency of Release Year", fontsize=20)
plt.xlabel("Year", fontsize=15)
plt.ylabel("Frequency", fontsize=15)
plt.show()

# %%
#How many movies and tv shows are in the dataset
NET_data.groupby('type').type.count()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
sns.countplot(NET_data['type'])
# Out:
# C:\Users\e6430\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='type', ylabel='count'>

# %%
#What movies where released in year 2000?
NET_data['Years']= NET_data['Date_Released'].dt.year

# %%
NET_data [(NET_data['type']== 'Movie') & (NET_data['Years']== 2015)]  #Filtering
# Out:
#      show_id   type                                              title  \
# 5876   s5877  Movie                       Marco Polo: One Hundred Eyes
# 5878   s5879  Movie                  Mike Epps: Don't Take It Personal
# 5879   s5880  Movie                                   The Ridiculous 6
# 5880   s5881  Movie  Trailer Park Boys: Drunk, High and Unemployed:...
# 5881   s5882  Movie                            A Very Murray Christmas
# 5883   s5884  Movie                       Naomi and Ely's No Kiss List
# 5884   s5885  Movie                     John Mulaney: The Comeback Kid
# 5886   s5887  Movie                             Manson Family Vacation
# 5887   s5888  Movie  Walt Disney Animation Studios Short Films Coll...
# 5889   s5890  Movie                                            Results
# 5890   s5891  Movie             Anthony Jeselnik: Thoughts and Prayers
# 5891   s5892  Movie                                Beasts of No Nation
# ...

# %%
#Titles of TV shows realsed in Canada.
NET_data [(NET_data['type']== 'TV Show') & (NET_data['country']== 'Canada')] #Filtering
# Out:
#      show_id     type                                       title  \
# 510     s511  TV Show                                     Between
# 521     s522  TV Show                           Kim's Convenience
# 535     s536  TV Show                      Some Assembly Required
# 544     s545  TV Show                                Workin' Moms
# 1065   s1066  TV Show                                     Slasher
# 1354   s1355  TV Show                                   Heartland
# 1383   s1384  TV Show                                  Blown Away
# 1746   s1747  TV Show                            Can You Hear Me?
# 1758   s1759  TV Show                                LEGO Ninjago
# 2106   s2107  TV Show                       Rust Valley Restorers
# 2160   s2161  TV Show                             Ever After High
# 2174   s2175  TV Show                          My Perfect Landing
# 2178   s2179  TV Show                               The Next Step
# ...

# %%
NET_data [(NET_data['type']== 'TV Show') & (NET_data['country']== 'Canada')] ['title'] #filtering Titles only
# Out:
# 510                                        Between
# 521                              Kim's Convenience
# 535                         Some Assembly Required
# 544                                   Workin' Moms
# 1065                                       Slasher
# 1354                                     Heartland
# 1383                                    Blown Away
# 1746                              Can You Hear Me?
# 1758                                  LEGO Ninjago
# 2106                         Rust Valley Restorers
# 2160                               Ever After High
# 2174                            My Perfect Landing
# 2178                                 The Next Step
# 2480        Trailer Park Boys: The Animated Series
# 2542                          True: Terrific Tales
# 2552                       Restaurants on the Edge
# 2554                                    The Hollow
# 2588                                       Oh Yuck
# ...

# %%
filtered_data = NET_data[(NET_data['type']== 'TV Show') & (NET_data['country']== 'Canada')]
titles = filtered_data['title'].values

for i, title in enumerate(titles):
    plt.text(0, i, title, fontsize=12)

plt.yticks([])
plt.title("TV Shows from Canada", fontsize=15)
plt.show()

# %%
#Top 10 Directors with the highest no. of realised TV shows and Movies on Netflix
NET_data['director'].value_counts().head(10)     #using value count function and added head(10) to limit output to 10
# Out:
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: director, dtype: int64

# %%
#Plot the bar chart
plt.figure(figsize=(10,4))
NET_data['director'].value_counts().head(15).plot(kind='bar', color='Teal').set_title('Top 15 Directors With highest TV show on Netflix', fontsize=13)
plt.show()

# %%
#Show data, where Categories, Type and country columns are equal to movie, comedy and united kingdom respectivly
NET_data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
N_data =NET_data.dropna()

# %%
NET_data [(NET_data['type']== 'Movies') &(NET_data['listed_in']== 'Comedies') | (NET_data['country']== 'United Kingdom')]
# Out:
#      show_id     type                                   title  \
# 8         s9  TV Show           The Great British Baking Show
# 32       s33  TV Show                           Sex Education
# 65       s66  TV Show                            Numberblocks
# 72       s73  TV Show  Jack Whitehall: Travels with My Father
# 98       s99  TV Show               Octonauts: Above & Beyond
# ...      ...      ...                                     ...
# 8740   s8741  TV Show                             Wild Alaska
# 8741   s8742  TV Show                             Wild Arabia
# 8744   s8745    Movie                                Williams
# 8758   s8759  TV Show                  World's Busiest Cities
# 8786   s8787    Movie                            You Can Tutu
#
#              director                                               cast  \
# 8     Andy Devonshire  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# ...

# %%
#How many movies and TVshows was Tom Curies cast in?
N_data [N_data['cast'].str.contains('Tom Cruise') ]
# Out:
#      show_id   type     title              director  \
# 341     s342  Movie  Magnolia  Paul Thomas Anderson
# 1254   s1255  Movie  Rain Man        Barry Levinson
#
#                                                    cast        country  \
# 341   John C. Reilly, Philip Baker Hall, Tom Cruise,...  United States
# 1254  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#           date_added  release_year rating duration  \
# 341   August 1, 2021          1999      R  189 min
# 1254   March 1, 2021          1988      R  134 min
#
#                        listed_in  \
# 341   Dramas, Independent Movies
# 1254      Classic Movies, Dramas
#
#                                             description Date_Released   Years
# 341   Through chance, history and divine interventio...    2021-08-01  2021.0
# 1254  Motivated by money, a selfish workaholic seeki...    2021-03-01  2021.0

# %%
#What are the diffrent ratings defined by Netflix?
NET_data .rating.nunique()
# Out:
# 17

# %%
#How Many movies have the 'TV-14' rating in Canada?
NET_data .rating.unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
NET_data[(NET_data['type'] == 'Movies') & (NET_data['rating'] == 'TV-14') ].shape
# Out:
# (0, 14)

# %%
filtered_data = NET_data[(NET_data['rating']== 'TV-14') & (NET_data['country']== 'Canada')]
print(filtered_data.shape[0])
# Out:
# 26

# %%
#How Many TV Shows has the "R" Rating after 2018?
NET_data [(NET_data['rating']== 'R') &(NET_data['Years']< 2018)]
# Out:
#      show_id   type                                 title  \
# 5101   s5102  Movie                        Fun Mom Dinner
# 5102   s5103  Movie           Goon: Last of the Enforcers
# 5116   s5117  Movie  Jeremiah Tower: The Last Magnificent
# 5167   s5168  Movie                              Mudbound
# 5179   s5180  Movie              Jerry Seinfeld: Comedian
# ...      ...    ...                                   ...
# 8678   s8679  Movie                       Vincent N Roxxy
# 8715   s8716  Movie                   Welcome to New York
# 8731   s8732  Movie                     While We're Young
# 8765   s8766  Movie                                    XX
# 8768   s8769  Movie                     Y Tu Mamá También
#
#                                                director  \
# 5101                                      Alethea Jones
# 5102                                       Jay Baruchel
# 5116                                     Lydia Tenaglia
# ...

# %%
#Find the maximum duration of a Movie or Show in Netflix.
NET_data['duration'].unique()
# Out:
# array(['90 min', '2 Seasons', '1 Season', '91 min', '125 min',
#        '9 Seasons', '104 min', '127 min', '4 Seasons', '67 min', '94 min',
#        '5 Seasons', '161 min', '61 min', '166 min', '147 min', '103 min',
#        '97 min', '106 min', '111 min', '3 Seasons', '110 min', '105 min',
#        '96 min', '124 min', '116 min', '98 min', '23 min', '115 min',
#        '122 min', '99 min', '88 min', '100 min', '6 Seasons', '102 min',
#        '93 min', '95 min', '85 min', '83 min', '113 min', '13 min',
#        '182 min', '48 min', '145 min', '87 min', '92 min', '80 min',
#        '117 min', '128 min', '119 min', '143 min', '114 min', '118 min',
#        '108 min', '63 min', '121 min', '142 min', '154 min', '120 min',
#        '82 min', '109 min', '101 min', '86 min', '229 min', '76 min',
#        '89 min', '156 min', '112 min', '107 min', '129 min', '135 min',
#        '136 min', '165 min', '150 min', '133 min', '70 min', '84 min',
# ...

# %%
NET_data[['Minutes','Unit']]= NET_data['duration'].str.split(' ', expand = True)

# %%
NET_data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
NET_dataTV=NET_data[NET_data['type']== 'TV Show']

# %%
NET_dataTV.head(2)
# Out:
#   show_id     type          title         director  \
# 1      s2  TV Show  Blood & Water              NaN
# 2      s3  TV Show      Ganglands  Julien Leclercq
#
#                                                 cast       country  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           NaN
#
#            date_added  release_year rating   duration  \
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
#                                          description Date_Released   Years  \
# 1  After crossing paths at a party, a Cape Town t...    2021-09-24  2021.0
# 2  To protect his family from a powerful drug lor...    2021-09-24  2021.0
#
#   Minutes     Unit
# 1       2  Seasons
# ...

# %%
NET_dataTV['country'].value_counts()
# Out:
# United States                                    760
# United Kingdom                                   213
# Japan                                            169
# South Korea                                      158
# India                                             79
#                                                 ...
# Belarus                                            1
# United Kingdom, Australia                          1
# France, Australia, Germany                         1
# Australia, New Zealand, United States              1
# United States, France, South Korea, Indonesia      1
# Name: country, Length: 196, dtype: int64

# %%
NET_dataTV['country'].value_counts().head()
# Out:
# United States     760
# United Kingdom    213
# Japan             169
# South Korea       158
# India              79
# Name: country, dtype: int64

# %%
#Plot Bar
plt.figure(figsize=(10,4))
sns.countplot(x='country', data=NET_data, order=NET_data['country'].value_counts().head().index)
plt.xlabel("Country")
plt.ylabel("Frequency")
plt.title("Top 5 Frequent Countries", fontsize=15)
plt.show()

# %%
NET_data.sort_values(by = 'Years').head(2)
# Out:
#      show_id     type                 title              director  \
# 5957   s5958    Movie  To and From New York  Sorin Dan Mihalcescu
# 6611   s6612  TV Show       Dinner for Five                   NaN
#
#                                                    cast        country  \
# 5957  Barbara King, Shaana Diya, John Krisiukenas, Y...  United States
# 6611                                                NaN  United States
#
#             date_added  release_year rating  duration  \
# 5957   January 1, 2008          2006  TV-MA    81 min
# 6611  February 4, 2008          2007  TV-MA  1 Season
#
#                                   listed_in  \
# 5957  Dramas, Independent Movies, Thrillers
# 6611           Stand-Up Comedy & Talk Shows
#
#                                             description Date_Released   Years  \
# 5957  While covering a story in New York City, a Sea...    2008-01-01  2008.0
# 6611  In each episode, four celebrities join host Jo...    2008-02-04  2008.0
#
# ...

# %%
NET_data.sort_values(by = 'Years', ascending = False).head(2)
# Out:
#     show_id   type                 title         director  \
# 0        s1  Movie  Dick Johnson Is Dead  Kirsten Johnson
# 996    s997  Movie            HOMUNCULUS  Takashi Shimizu
#
#                                                   cast        country  \
# 0                                                  NaN  United States
# 996  Go Ayano, Ryo Narita, Yukino Kishii, Anna Ishi...          Japan
#
#              date_added  release_year rating duration  \
# 0    September 25, 2021          2020  PG-13   90 min
# 996      April 22, 2021          2021  TV-MA  116 min
#
#                                           listed_in  \
# 0                                     Documentaries
# 996  Horror Movies, International Movies, Thrillers
#
#                                            description Date_Released   Years  \
# 0    As her father nears the end of his life, filmm...    2021-09-25  2021.0
# 996  Truth and illusion blurs when a homeless amnes...    2021-04-22  2021.0
#
# ...
